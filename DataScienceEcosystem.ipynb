# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, the Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ## Author
# Samuel Siegel

# %% [markdown]
# **Objectives**
# - Be able to list popular languages for data science
# - Be able to list commonly used libraries in data science
# - Be able to list popular tools for data science
# - Be able to complete basic arithmetic operations in Python

# %% [markdown]
# Some popular languages that data scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by data scientists include:
#
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn
# 5. Keras

# %% [markdown]
# | Data Science Tools |
# | ------------------ |
# | Jupyter |
# | RStudio |
# | Hadoop |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
#This is a simple arithmetic expression, multiplying then adding integers.
x = (3 * 4) + 5
print(x)
# Out:
# 17

# %%
#This will convert minutes to hours by dividing by 60.
x = 200
y = x/60
print(str(x) + " minutes is equal to " + str(y) + " hours")
# Out:
# 200 minutes is equal to 3.3333333333333335 hours
